# %% [markdown]
# <a href="https://colab.research.google.com/github/VaishaliMJ/Deep-Learning/blob/main/BidirectionalRNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from keras.datasets import imdb
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense,SimpleRNN,Bidirectional,GRU,Dropout
from keras.preprocessing.sequence import pad_sequences

# %%
numWords=10000
(x_train,y_train),(x_test,y_test)=imdb.load_data(num_words=numWords)
# Out:
# ...
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
maxLen=100
x_train=pad_sequences(x_train,maxlen=maxLen,padding="post",truncating="post")
x_test=pad_sequences(x_test,maxlen=maxLen,padding="post",truncating="post")

# %%
from keras.src import Input
embeddingDim=32

model=Sequential()
model.add(Input(shape=(100,)))
model.add(Embedding(numWords,embeddingDim,input_length=maxLen))
model.add(Dropout(0.25))
model.add(SimpleRNN(5))


model.add(Dense(1,activation="sigmoid"))

model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

model.summary()
history=model.fit(x_train, y_train, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# Model: "sequential_16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_15 (Embedding)        │ (None, 100, 32)        │       320,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 100, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_8 (SimpleRNN)        │ (None, 5)              │           190 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 320,196 (1.22 MB)
#  Trainable params: 320,196 (1.22 MB)
# ...

# %%
from keras.src import Input
embeddingDim=32

modelBi=Sequential()
modelBi.add(Input(shape=(100,)))
modelBi.add(Embedding(numWords,embeddingDim,input_length=maxLen))
modelBi.add(Dropout(0.25))

modelBi.add(Bidirectional(SimpleRNN(5)))
modelBi.add(Dropout(0.25))

modelBi.add(Dense(1,activation="sigmoid"))

modelBi.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

modelBi.summary()

history_modelBi=modelBi.fit(x_train, y_train, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# Model: "sequential_15"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_14 (Embedding)        │ (None, 100, 32)        │       320,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 100, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_9 (Bidirectional) │ (None, 10)             │           380 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 10)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 1)              │            11 │
# ...

# %%
from keras.src import Input
embeddingDim=32

modelLSTM=Sequential()
modelLSTM.add(Input(shape=(100,)))
modelLSTM.add(Embedding(numWords,embeddingDim,input_length=maxLen))
modelLSTM.add(Bidirectional(LSTM(5)))
modelLSTM.add(Dropout(0.25))
modelLSTM.add(Dense(1,activation="sigmoid"))

modelLSTM.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

modelLSTM.summary()

history_ModelLSTM=modelLSTM.fit(x_train, y_train, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_17"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_16 (Embedding)        │ (None, 100, 32)        │       320,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_10                │ (None, 10)             │         1,520 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 10)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
from keras.src import Input
embeddingDim=32

modelGRU=Sequential()
modelGRU.add(Input(shape=(100,)))
modelGRU.add(Embedding(numWords,embeddingDim,input_length=maxLen))
modelGRU.add(Bidirectional(GRU(5)))
modelGRU.add(Dropout(0.25))
modelGRU.add(Dense(1,activation="sigmoid"))

modelGRU.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

modelGRU.summary()

history_modelGRU=modelGRU.fit(x_train, y_train, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_18"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_17 (Embedding)        │ (None, 100, 32)        │       320,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_11                │ (None, 10)             │         1,170 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 10)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer=Tokenizer(num_words=10000)

def predict_Sentiment(modelName,review):
  testSeq=tokenizer.texts_to_sequences([review])

  review=pad_sequences(testSeq,maxlen=200)
  predictedResult=modelName.predict(review)
  sentiment = "positive" if predictedResult[0][0] > 0.5 else "negative"
  return sentiment

# %%
review="The movie was ok,But it was too lengthy,I am not happy about movie"

prediction_model=predict_Sentiment(model,review)
print(f"Prediction with Simple RNN Model:{prediction_model}")

prediction_BIModel=predict_Sentiment(modelBi,review)
print(f"Prediction with Bi-Directional Model:{prediction_BIModel}")


prediction_LSTMmodel=predict_Sentiment(modelLSTM,review)
print(f"Prediction with Bi-Directional LSTM Model:{prediction_LSTMmodel}")


prediction_GRUModel=predict_Sentiment(modelGRU,review)
print(f"Prediction with Bi-Directional GRU Model :{prediction_GRUModel}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Prediction with Simple RNN Model:positive
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Prediction with Bi-Directional Model:positive
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Prediction with Bi-Directional LSTM Model:positive
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Prediction with Bi-Directional GRU Model :negative
