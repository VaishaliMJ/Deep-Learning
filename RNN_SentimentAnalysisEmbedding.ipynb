# %% [markdown]
# <a href="https://colab.research.google.com/github/VaishaliMJ/Deep-Learning/blob/main/RNN_SentimentAnalysisEmbedding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
docs=['India is my country',
      'I love India',
      'Nature is beautiful',
      'Food was tasty',
      'Movie was not good',
      'Paper was difficult']

# %%
import keras
from keras.src.legacy.preprocessing.text import Tokenizer
tokenizer=Tokenizer(oov_token='<test>')

# %%
tokenizer.fit_on_texts(docs)

# %%
len(tokenizer.word_index)
# Out:
# 17

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('india', 2),
#              ('is', 2),
#              ('my', 1),
#              ('country', 1),
#              ('i', 1),
#              ('love', 1),
#              ('nature', 1),
#              ('beautiful', 1),
#              ('food', 1),
#              ('was', 3),
#              ('tasty', 1),
#              ('movie', 1),
#              ('not', 1),
#              ('good', 1),
#              ('paper', 1),
#              ('difficult', 1)])

# %%
tokenizer.document_count
# Out:
# 6

# %%
sequences=tokenizer.texts_to_sequences(docs)
sequences
# Out:
# [[3, 4, 5, 6],
#  [7, 8, 3],
#  [9, 4, 10],
#  [11, 2, 12],
#  [13, 2, 14, 15],
#  [16, 2, 17]]

# %%
from keras.preprocessing.sequence import pad_sequences
sequences=pad_sequences(sequences,padding='post')
sequences
# Out:
# array([[ 3,  4,  5,  6],
#        [ 7,  8,  3,  0],
#        [ 9,  4, 10,  0],
#        [11,  2, 12,  0],
#        [13,  2, 14, 15],
#        [16,  2, 17,  0]], dtype=int32)

# %%
from keras import Sequential
from keras.layers import Embedding

model=Sequential()
model.add(keras.Input(shape=(4,)))
model.add(Embedding(18,output_dim=2,input_length=4,trainable=True))
model.summary()
# Out:
# Model: "sequential_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_11 (Embedding)        │ (None, 4, 2)           │            36 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 36 (144.00 B)
#  Trainable params: 36 (144.00 B)
#  Non-trainable params: 0 (0.00 B)
